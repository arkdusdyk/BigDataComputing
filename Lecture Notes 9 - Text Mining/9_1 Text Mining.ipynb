# %%
import requests
x = requests.get('https://w3schools.com')
print(x)
print(x.status_code)  # request에 대한 status_code확인 (200 : success)
# Out:
# <Response [200]>
# 200

# %%
import requests
# the required first parameter of the 'get' method is the 'url'
x = requests.get('https://w3schools.com/python/demopage.htm')
# print the header
print(x.headers)
# Out:
# {'Content-Encoding': 'gzip', 'Accept-Ranges': 'bytes', 'Age': '6207', 'Cache-Control': 'public,max-age=14400,public', 'Content-Security-Policy': "frame-ancestors 'self' https://mycourses.w3schools.com;", 'Content-Type': 'text/html', 'Date': 'Wed, 26 May 2021 13:26:32 GMT', 'Etag': '"1aa65348c71ad51:0"', 'Last-Modified': 'Tue, 04 Jun 2019 11:18:49 GMT', 'Server': 'ECS (tkb/733E)', 'Vary': 'Accept-Encoding', 'X-Cache': 'HIT', 'X-Content-Security-Policy': "frame-ancestors 'self' https://mycourses.w3schools.com;", 'X-Powered-By': 'ASP.NET', 'Content-Length': '178'}

# %%
import requests
# the required first parameter of the 'get' method is the 'url'
x = requests.get('https://w3schools.com/python/demopage.htm')

# print the response text (the content of the requested file)
print(x.text)
# Out:
# <!DOCTYPE html>
# <html>
# <body>
#
# <h1>This is a Test Page</h1>
#
# </body>
# </html>

# %%
import requests
from bs4 import BeautifulSoup

# 크롤링할 사이트 주소를 정의
source_url = "https://namu.wiki/RecentChanges"
req = requests.get(source_url)
html = req.content   # Response 의 body를 binary 파일 형태로 access, 자동으로 decoding
soup = BeautifulSoup(html, 'lxml')
contents_table = soup.find(name='table')
table_body = contents_table.find(name = 'tbody')
table_rows = table_body.find_all(name = 'tr')

# a 태그의 href속성을 리스트로 추출, 크롤링할 페이지 리스트를 생성
page_url_base = 'https://namu.wiki'
page_urls = []
for index in range(0, len(table_rows)):
    first_td = table_rows[index].find_all('td')[0]
    td_url = first_td.find_all('a')
    if len(td_url) > 0:
        page_url = page_url_base + td_url[0].get('href')
        if 'png' not in page_url:  # not image link
            page_urls.append(page_url)

# 중복 url 제거 (using set)
page_urls = list(set(page_urls))
for page in page_urls[:5]:
    print(page)
# Out:
# https://namu.wiki/w/%ED%98%B8%EC%8B%9C%20%EC%95%84%EB%A9%94%EB%A6%AC
# https://namu.wiki/w/%EC%9D%B4%EB%AF%BC%ED%98%81(BTOB)
# https://namu.wiki/w/%EC%95%A0%EB%8D%A4%20%EB%93%9C%EB%9D%BC%EC%9D%B4%EB%B2%84
# https://namu.wiki/w/%EB%B6%84%EB%A5%98:%EB%AC%B4%ED%95%9C%EB%8F%84%EC%A0%84/2009%EB%85%84
# https://namu.wiki/w/MrBeast

# %%
# 하나의 최근 변경된 문서를 크롤링
req = requests.get(page_urls[0])
html = req.content
soup = BeautifulSoup(html, 'lxml')
contents_table = soup.find(name = 'article')
title = contents_table.find_all('h1')[0]
content_paragraphs = contents_table.find_all(name = 'div', attrs = {"class":"wiki-paragraph"})
content_corpus_list = []

for paragraphs in content_paragraphs:
    content_corpus_list.append(paragraphs.text)
content_corpus = "".join(content_corpus_list)

print(title.text)
print('\n')
print(content_corpus)
# Out:
# 호시 아메리
#
#
# 주의. 성(性)적인 요소가 있습니다.이 표제어에는 성(性)적인 요소가 있기 때문에, 대한민국의 주요 포털 사이트는 이 표제어와 관련된 표현의 검색을 제한할 수 있습니다.AV 배우 프로필이름호시 아메리星あめり, Ameri Hoshi출생지 일본, 와카야마현생년월일1991년 11월 30일 (29세)신장158cm쓰리사이즈B85(C) / W58 / H88혈액형O형소속사NAX프로모션데뷔일2017년 12월 7일취미만화,미니카,프라모델,에어건,수영,마작,서예,스누피 수집링크  1. 소개2. 출연작품2.1. 외모2.2. 인물2.3. 연기3. 그 외 정보4. 여담5. 관련 문서·일본의 AV 여배우. 1991년생. 애칭은 아메린(あめりん)이라 불린다.·2017년 12월 첫 작품으로 SOD크리에이터를 통해 데뷔했다. 적당히 마른 몸매와 더불어 감정 잡는 연기가 출중하다.·2021년 5월 현재 공식적으로는 240편이 넘는 작품에 출연하였으며 레즈작 찍고 싶어서 트위터에서 자주 타령한다.== 데뷔/활동 ==·2017 년 12 월 대형 AV제작사 " SOD 크리에이트 '에서 AV 데뷔.·2019 년 부터 크라우드 펀딩 ' 라포
�고 단독 주연으로 나온    작품이다. 2018년 7월 SORA-188에서 야외물 해금.2018년 8월 ONEZ-153 : 이 작품에선 방뇨 씬을 해금했다.2018년 9월 NKD-226 : 처음으로 따귀 씬을 찍었다.2018년 9월 ZNN-005 : 붓카케 & 골든샤워 해금2018년 10월 ABP-783 : 같은 소속사 대선배 스즈무라 아이리의 작품에서 레즈 씬 파트너로 보조 출연했다.2018년 10월 GS-1911 : 1박 2일 온천여행 컨셉이었는데, 아메리의 유부녀 연기와 안경이 잘어울린다.2018년 10월 SABA-463 : 아헤가오 더블피스를 시전했다.2018년 11월 LUXU-1037 : 스틸컷이 잘 나왔길래 그냥 올려봤다. 각선미가 유독 부각된 농밀물.2018년 12월 ALAS-006 : 호시 아메리가 직접 프로듀스한 작품. 빈유 컴플렉스가 있는 아메리가 거유를 탐한다는 내용.2018년 12월 DCV-122 : 호시 아메리의 실제 자기 얘기를 픽션과 적절하게 섞어놓은 페이크 다큐. 미니카 콜렉터인 것도 그렇고, 애니 굿즈 덕질로 방을 가득 채운 것도 실제 그녀의 모습에 가깝다. #출연작품 (2020년까지 업데이트됨)한국팬들 평으로는, 얼굴은 예쁜 편이다. 특히 소중이 헤어가 정글인게 특징이다.학창시절부터 수영을 했어서 등근육도 있고 큰 골반에 슬랜더로서 몸매가 나쁘지 않으며 다리가 예쁘다. #각선미금발로 염색했을 때 반응이 제일 좋았다.작품에서 자주 울기 때문에 울보라고 불린다. AV여배우 시이나 소라를 살짝 닮았다는 평이 많다.분위기 메이커, 동료 여배우들 이벤트에 게스트로 출연하거나 NAX소속사 망년회때 분위기를 이끄는 등 잘 웃고 성격이 좋은듯 하다. #인싸친한 여배우들은 '미타니 아카리'와 '콘노 히카루'이다.가라오케 가서 애니 송 부르는 것을 좋아한다.#아메리 노래1#아메리 노래2#아메리 노래3자타 공인 오타쿠라고 말하고 다닌다. 오타쿠라서 다른 여자와 만나면 어떻게 대화해야 할 지 잘 모른다고 한다. "어떤 드라마보고있어?」라고 패션 라든가 말해도 전혀 모르고 대화가 멈춰 버린다. 또, 붙임성 웃음을 띄우는 것 정도 밖에 할 줄 모른다고 한다. (인터뷰 中 발췌)술과 담배는 하지 않는다고 한다. (간혹 몇몇 작품에서 술을 마시긴 하나 몇잔 못먹고 헤롱거린다)특기는 수영이고, 최고 성적은 자유형 5위였다고 한다.고민이 있을 땐 수영장에 가며, 수영할 땐 아무생각 안해도 되서 좋다고 한다.취미는 만화, 애니메이션, 미니카, 프라모델, 에어소프트 , 수영, 마작, 서예, 애니송 듣고 부르기, 스누피 상품 수집하기.BL을 좋아한다.건프라도 좋아한다. 건담시리즈 이니셜D도 좋아한다.에어 건을 14자루나 갖고 있다. (2021년 기준)집에 미니카 키트+트랙이 있고 숍에 일한 전적으로 타미야 레이스를 주최시킨적이 있다고 한다. 에어소프트게임은 데뷔 전부터 일하던 가게에서 총을 팔고 있었기 때문에 공부하면서 배웠다고 한다. 재미가 들려 한달에 한두번 참여한다고 한다. (다만 에어건이 맞으면 꽤 쎄서 양쪽 가슴에 상처 난 적도 있었다)여담으로 사모아리 AV감독이 치녀 전문배우로 아메리를 꼽았다 M녀인 아메리가 처음으로 CMD-023작품에서 치녀물을 찍었는데 자연스럽게 연기를 잘했으며, 정신적으로 오르가즘을 느끼거나 능욕당하는 것도 좋아한다며 아는 사람만 아는 인재이며 언젠간 크게 대성할 여배우라고 극찬했다.비교적 늦은 나이에 데뷔해서 그런지 장르를 가리거나 성별을 가리지 않고 열심히 다작하고 있는 중이다. 다른 여배우들의 작품 콜라보 공개 러브콜을 받는 둥 인기가 좋다. [ 인터뷰 접기·펼치기 ] #출처1.자신의 매력포인트는 큰 눈과 엉덩이라고 한다. 2.좋아하는 계절은 겨울이며 크리스마스와 연말을 좋아한다고 한다. 3.가고 싶은 나라는 애니를 좋아 ...

# %%
# 하나의 최근 변경된 문서를 크롤링
req = requests.get(page_urls[0])
html = req.content
soup = BeautifulSoup(html, 'lxml')
contents_table = soup.find(name = 'article')
title = contents_table.find_all('h1')[0]
sub_title = contents_table.find_all('h2')[0]  #subtitle
content_paragraphs = contents_table.find_all(name = 'div', attrs = {"class":"wiki-paragraph"})
content_corpus_list = []

for paragraphs in content_paragraphs:
    content_corpus_list.append(paragraphs.text)
content_corpus = "".join(content_corpus_list)

print(title.text)
print('\n')
print(sub_title.text)
print('\n')
print(content_corpus)
# Out:
# 호시 아메리
#
#
# 분류
#
#
# 주의. 성(性)적인 요소가 있습니다.이 표제어에는 성(性)적인 요소가 있기 때문에, 대한민국의 주요 포털 사이트는 이 표제어와 관련된 표현의 검색을 제한할 수 있습니다.AV 배우 프로필이름호시 아메리星あめり, Ameri Hoshi출생지 일본, 와카야마현생년월일1991년 11월 30일 (29세)신장158cm쓰리사이즈B85(C) / W58 / H88혈액형O형소속사NAX프로모션데뷔일2017년 12월 7일취미만화,미니카,프라모델,에어건,수영,마작,서예,스누피 수집링크  1. 소개2. 출연작품2.1. 외모2.2. 인물2.3. 연기3. 그 외 정보4. 여담5. 관련 문서·일본의 AV 여배우. 1991년생. 애칭은 아메린(あめりん)이라 불린다.·2017년 12월 첫 작품으로 SOD크리에이터를 통해 데뷔했다. 적당히 마른 몸매와 더불어 감정 잡는 연기가 출중하다.·2021년 5월 현재 공식적으로는 240편이 넘는 작품에 출연하였으며 레즈작 찍고 싶어서 트위터에서 자주 타령한다.== 데뷔/활동 ==·2017 년 12 월 대형 AV제작사 " SOD 크리에이트 '에서 AV 데뷔.·2019 년 부터 크라우드 펀딩 ' 라포르노 펀딩'을 개최.·2019 년 특수촬영 히로인 AV 의 최고봉 '기가데미 어워드 2019'에서 최우수 작품상을 수상했다.·2019 년 4월 캣 파이트에서 경추 손상 부상을 입고 사진 촬영을 계속하고 있었지만, 점점 전신으로 부위가 퍼져 6개월 간 여배우를 휴업.(2020년 6월 1일부터 복귀) [ 부상부위 TMI ]오른허벅지 좌상경추(목뼈) 염좌우측 갈비뼈연골 손상양 팔꿈치 좌상양 무릎 좌상양 장골(골반) 타박상#진단서데뷔이유는 와카야마 현에서 의류 점원으로 일하다가 "엉망진창(滅茶苦茶)" 되고 싶어서 SOD에 동영상을 보내 AV 배우를 시작했다고 한다.실제론 일했던 취미 숍의 월급이 적었고 AV배우 유카씨를 동경해서 좋아하는 사람이 하는 일을 해보고 싶어서 데뷔했다고 한다.데뷔작 SDMU-244 작품상의 이름은 메구미(めぐみ). 그러나 이후에 곧 활동명을 '호시 아메리'(星あめり)로 정했다."좀 더 빨리 이 세계에 뛰어들었다면 좋았을 것이라고 자주 후
질로 방을 가득 채운 것도 실제 그녀의 모습에 가깝다. #출연작품 (2020년까지 업데이트됨)한국팬들 평으로는, 얼굴은 예쁜 편이다. 특히 소중이 헤어가 정글인게 특징이다.학창시절부터 수영을 했어서 등근육도 있고 큰 골반에 슬랜더로서 몸매가 나쁘지 않으며 다리가 예쁘다. #각선미금발로 염색했을 때 반응이 제일 좋았다.작품에서 자주 울기 때문에 울보라고 불린다. AV여배우 시이나 소라를 살짝 닮았다는 평이 많다.분위기 메이커, 동료 여배우들 이벤트에 게스트로 출연하거나 NAX소속사 망년회때 분위기를 이끄는 등 잘 웃고 성격이 좋은듯 하다. #인싸친한 여배우들은 '미타니 아카리'와 '콘노 히카루'이다.가라오케 가서 애니 송 부르는 것을 좋아한다.#아메리 노래1#아메리 노래2#아메리 노래3자타 공인 오타쿠라고 말하고 다닌다. 오타쿠라서 다른 여자와 만나면 어떻게 대화해야 할 지 잘 모른다고 한다. "어떤 드라마보고있어?」라고 패션 라든가 말해도 전혀 모르고 대화가 멈춰 버린다. 또, 붙임성 웃음을 띄우는 것 정도 밖에 할 줄 모른다고 한다. (인터뷰 中 발췌)술과 담배는 하지 않는다고 한다. (간혹 몇몇 작품에서 술을 마시긴 하나 몇잔 못먹고 헤롱거린다)특기는 수영이고, 최고 성적은 자유형 5위였다고 한다.고민이 있을 땐 수영장에 가며, 수영할 땐 아무생각 안해도 되서 좋다고 한다.취미는 만화, 애니메이션, 미니카, 프라모델, 에어소프트 , 수영, 마작, 서예, 애니송 듣고 부르기, 스누피 상품 수집하기.BL을 좋아한다.건프라도 좋아한다. 건담시리즈 이니셜D도 좋아한다.에어 건을 14자루나 갖고 있다. (2021년 기준)집에 미니카 키트+트랙이 있고 숍에 일한 전적으로 타미야 레이스를 주최시킨적이 있다고 한다. 에어소프트게임은 데뷔 전부터 일하던 가게에서 총을 팔고 있었기 때문에 공부하면서 배웠다고 한다. 재미가 들려 한달에 한두번 참여한다고 한다. (다만 에어건이 맞으면 꽤 쎄서 양쪽 가슴에 상처 난 적도 있었다)여담으로 사모아리 AV감독이 치녀 전문배우로 아메리를 꼽았다 M녀인 아메리가 처음으로 CMD-023작품에서 치녀물을 찍었는데 자연스럽게 연기를 잘했으며, 정신적으로 오르가즘을 느끼거나 능욕당하는 것도 좋아한다며 아는 사람만 아는 인재이며 언젠간 크게 대성할 여배우라고 극찬했다.비교적 늦은 나이에 데뷔해서 그런지 장르를 가리거나 성별을 가리지 않고 열심히 다작하고 있는 중이다. 다른 여배우들의 작품 콜라보 공개 러브콜을 받는 둥 인기가 좋다. [ 인터뷰 접기·펼치기 ] #출처1.자신의 매력포인트는 큰 눈과 엉덩이라고 한다. 2.좋아하는 계절은 겨울이며 크리스마스와 연말을 좋아한다고 한다. 3.가고 싶은 나라는 애니를 좋아 ...

# %%
# %matplotlib inline
# Jupyter notebook 을 실행한 browser에 바로 그림이 그려지도록 해주는 코드

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore") #Error가 아닌 warning들을 무시
import requests
from bs4 import BeautifulSoup
import re   # regular expression

# 크롤링할 사이트 주소 정의
source_url = "https://namu.wiki/RecentChanges"

#사이트의 html구조에 기반해 크롤링 수행
req = requests.get(source_url)
html = req.content
soup = BeautifulSoup(html, 'lxml')
contents_table = soup.find(
e46="">203.228.12.162</a> </div> <div aria-hidden="true" class="tooltip popover vue-popover-theme" id="popover_0p2hy4n66l" style="visibility:hidden;display:none;" tabindex="0"><div class="wrapper"><div class="tooltip-inner popover-inner" style="position:relative;"><div><div data-v-38195e46=""><a data-v-38195e46="" data-v-4f23b670="" href="/contribution/ip/203.228.12.162/document">기여내역</a> <!-- --> <!-- --></div></div> <div class="resize-observer" data-v-b329ee4c="" tabindex="-1"></div></div> <div class="tooltip-arrow popover-arrow"></div></div></div></div> <!-- --></td> <td data-v-36de48c1=""><time data-v-36de48c1="" datetime="2021-05-26T13:26:34.000Z">2021-05-26 13:26:34</time></td></tr>, <tr data-v-36de48c1=""><td data-v-36de48c1=""><a data-v-36de48c1="" href="/w/%EC%9E%90%EB%82%B3%EB%8C%80/%ED%8F%89%EA%B0%80">자낳대/평가</a> <a data-v-36de48c1="" href="/history/%EC%9E%90%EB%82%B3%EB%8C%80/%ED%8F%89%EA%B0%80">[역사]</a> <a data-v-36de48c1="" href="/diff/%EC%9E%90%EB%82%B3%EB%8C%80/%ED%8F%89%EA%B0%80?rev=20&amp;oldrev=19">[비교]</a> <a data-v-36de48c1="" href="/discuss/%EC%9E%90%EB%82%B3%EB%8C%80/%ED%8F%89%EA%B0%80">[토론]</a> <span data-v-36de48c1="">(<span class="p" data-v-36de48c1="" data-v-3ee54395="">+14</span>)</span></td> <td data-v-36de48c1=""><div class="v-popover" data-v-36de48c1="" data-v-38195e46=""><div aria-describedby="popover_hlfmkkzpyl" class="trigger" style="display:inline-block;"><a class="u" data-v-38195e46="">jikevin1127</a> </div> <div aria-hidden="true" class="tooltip popover ...

# %%
# a 태그의 href 속성을 리스트로 추출, 크롤링할 페이지 리스트 생성
page_url_base = "https://namu.wiki"
page_urls = []
for index in range(0, len(table_rows)):
    first_td = table_rows[index].find_all('td')[0]
    td_url = first_td.find_all('a')
    if len(td_url) > 0:
        page_url = page_url_base + td_url[0].get('href')
        if 'png' not in page_url:
            page_urls.append(page_url)
#중복 url 제거
page_urls = list(set(page_urls))
for page in page_urls[:5]:
    print(page)
# Out:
# https://namu.wiki/w/%ED%98%B8%EC%8B%9C%20%EC%95%84%EB%A9%94%EB%A6%AC
# https://namu.wiki/w/%EC%9D%B4%EB%AF%BC%ED%98%81(BTOB)
# https://namu.wiki/w/%EC%95%A0%EB%8D%A4%20%EB%93%9C%EB%9D%BC%EC%9D%B4%EB%B2%84
# https://namu.wiki/w/%EB%B6%84%EB%A5%98:%EB%AC%B4%ED%95%9C%EB%8F%84%EC%A0%84/2009%EB%85%84
# https://namu.wiki/w/MrBeast

# %%
import pandas as pd
columns = ['title', 'category', 'content_text']
df = pd.DataFrame(columns = columns)
#각 페이지별 '제목', '카테고리', '본문' 정보를 데이터 프레임으로 만든다.
for page_url in page_urls:
    #사이트 html 구조에 기반해서 크롤링 수행
    req = requests.get(page_url)
    html = req.content
    soup = BeautifulSoup(html, 'lxml')
    contents_table = soup.find(name = 'article')
    title = contents_table.find_all('h1')[0]
    
    #카테고리 정보가 없는 경우 확인
    if len(contents_table.find_all('ul')) > 0:
        category = contents_table.find_all('ul')[0]
    else:
        category = None
    content_paragraphs = contents_table.find_all(name = 'div', attrs = {"class":"wiki-paragraph"})
    content_corpus_list = []
    
    #페이지 내 제목 정보에서 개행 문자를 제거한 뒤 추출. 만약 없는 경우, 빈 문자열로 대체
    if title is not None:
        row_title = title.text.replace('\n', ' ')
    else:
        row_title = ''
    
    # 페이지 내 본문 정보에서 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체
    if content_paragraphs is not None:
        for paragraphs in content_paragraphs:
            if paragraphs is not None:
                content_corpus_list.append(paragraphs.text.replace('\n',' '))
            else:
                content_corpus_list.append("")
    else:
        content_corpus_list.append("")
    
    # 페이지 내 카테고리 정보에서 "분류"라는 단어와 개행 문자를 제거한 뒤 추출
    # 만약 없는 경우 빈 문자열로 대체
    if category is not None:
        row_category = category.text.replace('\n', ' ')
    else:
        row_category = ''
    
    #모든 정보를 하나의 데이터 프레임에 저장.
    row = [row_title, row_category, "".join(content_corpus_list)]
    series = pd.Series(row, index=df.columns)
    df = df.append(series, ignore_index = True)

# %%
# 데이터 프레임을 출력
df.head(10)
# Out:
#             title                                           category  \
# 0         호시 아메리                 AV 여배우/ㅎ1991년 출생2017년 데뷔와카야마현 출신 인물
# 1      이민혁(BTOB)   BTOBBTOB 4U한국 남가수/ㅇ한국 남배우/ㅇ한국의 남성 래퍼/ㅇ1990년 출생...
# 2        애덤 드라이버                미국의 남배우/ㅇ1983년 출생샌디에이고 출신 인물2009년 데뷔
# 3  분류:무한도전/2009년                                   무한도전2009년 방송 프로그램
# 4        MrBeast          유튜버/M1998년 출생노스캐롤라이나 주 출신 인물커스텀 플레이 버튼 수상자
# 5         한국방송공사                                              한국방송공사
# 6         애덤 부시니                         미국의 야구 선수1987년 출생오클랜드 출신 인물
# 7  날아다니는 스파게티 괴물                                              패러디 종교
# 8         루안 라우드                                             라우드 하우스
# 9  분류:무한도전/2017년                                   무한도전2017년 방송 프로그램
#
#                                         content_text
# 0  주의. 성(性)적인 요소가 있습니다.이 표제어에는 성(性)적인 요소가 있기 때문에,...
# 1  HUTA [ 솔로 음반 ]    Piece of BTOB Vol. 5디지털 싱글(2...
# 2   역대 베니스 영화제 볼피 컵 - 남우주연상 제70회(2013년) →  제71회(2...
# 3     이 분류에 대한 설명은 무한도전/2009년 문서나  문서를 참고하십시오.문서가...
# 4  채널 이름MrBeast본명Jimmy Donaldson(지미 도날슨)출생1998년 5...
# 5     가입 후 15일이 지나야 편집 가능한 문서입니다.   KBS은(는) 여기로 연...
# 6   이름애덤 부시니(Adam Buschini)생년월일1987년 5월 6일학력캘리포니아...
# 7  이 문서는이 문단은 토론을 통해 옹호성 서술을 삭제하기(으)로 합의되었습니다. 합의...
# 8  라우드 家부모님장녀(첫째)로리 라우드차녀(둘째)레니 라우드3녀(셋째)루나 라우드4녀...
# 9  문서가 존재하는 무한도전 특집 (연도별)2007년 이전2008년2009년2010년2...

# %%
# 텍스트 정제 함수 : 한글 이외의 문자는 전부 제거합니다.
def text_cleaning(text):
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]+')
    result = hangul.sub('',text) #한글과 띄어쓰기를 제외한 모든 부분을 제거
    return result

# %%
print(text_cleaning(df['content_text'][0]))
# Out:
# 주의 성적인 요소가 있습니다이 표제어에는 성적인 요소가 있기 때문에 대한민국의 주요 포털 사이트는 이 표제어와 관련된 표현의 검색을 제한할 수 있습니다 배우 프로필이름호시 아메리  출생지 일본 와카야마현생년월일년 월 일 세신장쓰리사이즈    혈액형형소속사프로모션데뷔일년 월 일취미만화미니카프라모델에어건수영마작서예스누피 수집링크   소개 출연작품 외모 인물 연기 그 외 정보 여담 관련 문서일본의  여배우 년생 애칭은 아메린이라 불린다년 월 첫 작품으로 크리에이터를 통해 데뷔했다 적당히 마른 몸매와 더불어 감정 잡는 연기가 출중하다년 월 현재 공식적으로는 편이 넘는 작품에 출연하였으며 레즈작 찍고 싶어서 트위터에서 자주 타령한다 데뷔활동  년  월 대형 제작사   크리에이트 에서  데뷔 년 부터 크라우드 펀딩  라포르노 펀딩을 개최 년 특수촬영 히로인  의 
�때부터 낮가림을 하여 밖으로 잘 나가지 않았다고 한다 학창시절 특기 과목은 영어라고 한다 근데 영어로 말은 못한다고 한다 웃김자신의 자신있는 부위는 엉덩이 외에 쇄골이라고 한다후방주의좋아하는 역사 속의 인물은 신센구미의 야마나미 게이스케라고 한다좋아하는 페티쉬는 땀 흘리는 곳을 핥거나 쇄골보는 것을 좋아한다고 한다 작품 끝에서 아카리의 등땀을 보고 흥분하여 핥아준다잘하는 것은 서예좋아하는 여행지는 훗카이도에 가서 스키를 타는 것이었다고 한다 좋아하는 냄새는 포옹했을 때 남자의 뺨냄새라고 한다 좌우명은 좋아하는 일을 잘하게 하라 라고 한다일 동안 남자가 된다면 무엇을 하겠냐는 질문에는 일째는 자위일째는 여자와 짹스하기 일째는 메이드 카페로 간다고 한다 헌팅은 인생에서 번밖에 당해본 적이 없다고 한다 그 마저도 시간이 있냐 어디가냐고 물어봐 준게 다라고 한다 본인의 징크스는 빗을 누군가에게 빌려 그대로 사용하면 실연한다고 믿기에 빗을 번 흔들어서 사용한다고 한다 커엽좋아하는 코스프레는 롱 스커트에 노출이 없는 메이드 복장을 좋아한다고 한다 냉동식품중에 좋아하는 것은 새우그라탕이라고 한다 스트레스 푸는 방법은 노래방에 가서 혼자 노래하거나 원하는 물건을  ...

# %%
# 각 피처마다 데이터 전처리를 적용
df['title'] = df['title'].apply(lambda x: text_cleaning(x))
df['category'] = df['category'].apply(lambda x: text_cleaning(x))
df['content_text'] = df['content_text'].apply(lambda x: text_cleaning(x))
df.head(10)
# Out:
#             title                                           category  \
# 0         호시 아메리                             여배우ㅎ년 출생년 데뷔와카야마현 출신 인물
# 1            이민혁    한국 남가수ㅇ한국 남배우ㅇ한국의 남성 래퍼ㅇ년 출생노원구 출신 인물년 데뷔아이돌 ...
# 2        애덤 드라이버                         미국의 남배우ㅇ년 출생샌디에이고 출신 인물년 데뷔
# 3        분류무한도전년                                       무한도전년 방송 프로그램
# 4                               유튜버년 출생노스캐롤라이나 주 출신 인물커스텀 플레이 버튼 수상자
# 5         한국방송공사                                              한국방송공사
# 6         애덤 부시니                             미국의 야구 선수년 출생오클랜드 출신 인물
# 7  날아다니는 스파게티 괴물                                              패러디 종교
# 8         루안 라우드                                             라우드 하우스
# 9        분류무한도전년                                       무한도전년 방송 프로그램
#
#                                         content_text
# 0  주의 성적인 요소가 있습니다이 표제어에는 성적인 요소가 있기 때문에 대한민국의 주요...
# 1    솔로 음반         디지털 싱글미니 집  일본 음반        미니 집 ...
# 2   역대 베니스 영화제 볼피 컵  남우주연상 제회년   제회년   제회년 테미스 파누...
# 3    이 분류에 대한 설명은 무한도전년 문서나  문서를 참고하십시오문서가 존재하는 무...
# 4  채널 이름본명 지미 도날슨출생년 월 일세미국 노스캐롤라이나 주출생국가 미국키  가입...
# 5    가입 후 일이 지나야 편집 가능한 문서입니다  은는 여기로 연결됩니다 다른 뜻에...
# 6   이름애덤 부시니 생년월일년 월 일학력캘리포니아 폴리테크닉 주립대학교국적미국출신지캘...
# 7  이 문서는이 문단은 토론을 통해 옹호성 서술을 삭제하기으로 합의되었습니다 합의된 부...
# 8  라우드 부모님장녀첫째로리 라우드차녀둘째레니 라우드녀셋째루나 라우드녀넷째루안 라우드녀...
# 9           문서가 존재하는 무한도전 특집 연도별년 이전년년년년년년년년년년년방영 목록
